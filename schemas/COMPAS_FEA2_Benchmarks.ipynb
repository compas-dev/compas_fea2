# %% [markdown]
# # Step-by-Step backends verification in COMPAS_FEA_2

# %% [markdown]
# In this document, different basic structural elements will be provided for the sake of benchmarking, step-by-step class implementation, COMPAS_FEA2 framework verification, and perhaps educational purposes in the future.

# %% [markdown]
# For most of the cases, the examples are taken from *Finite Element Procedures* by *Klaus-Jürgen Bathe*, 2nd edition.
# > Here is the link to the book: [link text](https://enacshare.epfl.ch/dhEiMgBqUbxS4vnTZ53fo)

# %% [markdown]
# # **Example 1**: `cantilever beam`
#
# Refer to the BATHE's FE book, `Chapter 1`, `page 11`, `Fig. 1.4a`:

# %% [markdown]
# ![Cantilever_beam_BATHE.PNG](data:image/png;base64,...)

# %% [markdown]
# ### **Note**: Consider *Newton*, *tonne*, *mm*, and *sec* as the units
